# %% [markdown]
# <a href="https://colab.research.google.com/github/Kbcity1/checkpoint/blob/master/FileHandlingCheckPoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
with open('/content/Loan_prediction_dataset.csv', 'r') as file:
  data = np.genfromtxt(file, delimiter=',', names=True)
  print(data)
# Out:
# [(nan, nan, nan,  0., nan, nan,  5849., 0.00000000e+00,  nan, 360.,  1., nan, nan)
#  (nan, nan, nan,  1., nan, nan,  4583., 1.50800000e+03, 128., 360.,  1., nan, nan)
#  (nan, nan, nan,  0., nan, nan,  3000., 0.00000000e+00,  66., 360.,  1., nan, nan)
#  (nan, nan, nan,  0., nan, nan,  2583., 2.35800000e+03, 120., 360.,  1., nan, nan)
#  (nan, nan, nan,  0., nan, nan,  6000., 0.00000000e+00, 141., 360.,  1., nan, nan)
#  (nan, nan, nan,  2., nan, nan,  5417., 4.19600000e+03, 267., 360.,  1., nan, nan)
#  (nan, nan, nan,  0., nan, nan,  2333., 1.51600000e+03,  95., 360.,  1., nan, nan)
#  (nan, nan, nan, nan, nan, nan,  3036., 2.50400000e+03, 158., 360.,  0., nan, nan)
#  (nan, nan, nan,  2., nan, nan,  4006., 1.52600000e+03, 168., 360.,  1., nan, nan)
#  (nan, nan, nan,  1., nan, nan, 12841., 1.09680000e+04, 349., 360.,  1., nan, nan)
#  (nan, nan, nan,  2., nan, nan,  3200., 7.00000000e+02,  70., 360.,  1., nan, nan)
# ...

# %%
#Extract loan amounts from the "LoanAmount" column
loan_amount = data['LoanAmount']
print(loan_amount)
# Out:
# [ nan 128.  66. 120. 141. 267.  95. 158. 168. 349.  70. 109. 200. 114.
#   17. 125. 100.  76. 133. 115. 104. 315. 116. 112. 151. 191. 122. 110.
#   35. 120. 201.  74. 106. 114. 320.  nan 100. 144. 184. 110.  80.  47.
#   75. 134.  96.  88.  44. 144. 120. 144. 100. 120. 112. 134. 286.  97.
#   96. 135. 180. 144. 120.  99. 165.  nan 116. 258. 126. 312. 125. 136.
#  172.  97.  81.  95. 187. 113. 176. 110. 180. 130. 111.  nan 167. 265.
#   50. 136.  99. 104. 210. 175. 131. 188.  81. 122.  25.  nan 137.  50.
#  115. 131. 133. 151.  nan  nan 160. 100. 225. 120. 216.  94. 136. 139.
#  152.  nan 118. 185. 154.  85. 175. 259. 180.  44. 137.  81. 194.  93.
#  370.  nan 160. 182. 650.  74.  70.  25. 102. 290.  84.  88. 242. 129.
#  185. 168. 175. 122. 187. 100.  70.  30. 225. 125. 118. 152. 244. 113.
#   50. 600. 160. 187. 120. 255.  98. 275. 121. 158.  75. 182. 112. 129.
#   63. 200.  95. 700.  81. 187.  87. 116. 101. 495. 116. 102. 180.  67.
# ...

# %%
# Remove rows with missing values in the "LoanAmount" column
# This ensures that only valid loan amounts are used for analysis
data = data[~np.isnan(loan_amount)]
loan_amount = loan_amount[~np.isnan(loan_amount)]
print(loan_amount)
# Out:
# [128.  66. 120. 141. 267.  95. 158. 168. 349.  70. 109. 200. 114.  17.
#  125. 100.  76. 133. 115. 104. 315. 116. 112. 151. 191. 122. 110.  35.
#  120. 201.  74. 106. 114. 320. 100. 144. 184. 110.  80.  47.  75. 134.
#   96.  88.  44. 144. 120. 144. 100. 120. 112. 134. 286.  97.  96. 135.
#  180. 144. 120.  99. 165. 116. 258. 126. 312. 125. 136. 172.  97.  81.
#   95. 187. 113. 176. 110. 180. 130. 111. 167. 265.  50. 136.  99. 104.
#  210. 175. 131. 188.  81. 122.  25. 137.  50. 115. 131. 133. 151. 160.
#  100. 225. 120. 216.  94. 136. 139. 152. 118. 185. 154.  85. 175. 259.
#  180.  44. 137.  81. 194.  93. 370. 160. 182. 650.  74.  70.  25. 102.
#  290.  84.  88. 242. 129. 185. 168. 175. 122. 187. 100.  70.  30. 225.
#  125. 118. 152. 244. 113.  50. 600. 160. 187. 120. 255.  98. 275. 121.
#  158.  75. 182. 112. 129.  63. 200.  95. 700.  81. 187.  87. 116. 101.
#  495. 116. 102. 180.  67.  73. 260. 108. 120.  66.  58. 168. 188.  48.
# ...

# %%
#The mean
mean_loan_amount = np.mean(loan_amount)
print("Mean of Loan Amount:", mean_loan_amount)
# Out:
# Mean of Loan Amount: 146.41216216216216

# %%
#The median
median_loan_amount = np.median(loan_amount)
print("Median of Loan Amount:", median_loan_amount)
# Out:
# Median of Loan Amount: 128.0

# %%
#The standard deviation
std_loan_amount = np.std(loan_amount)
print("Standard Deviation of Loan Amount:", std_loan_amount)
# Out:
# Standard Deviation of Loan Amount: 85.51500809120331
